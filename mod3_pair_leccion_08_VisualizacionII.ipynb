# %%
# Librerías con Pandas::
import pandas as pd # Para trabajar con DataFrames
import numpy as np # Para trabajar con arrays y funciones matemáticas

# Librerías para visualización de datos:
import matplotlib.pyplot as plt # Para crear gráficos
import seaborn as sns # Para crear gráficos más atractivos y con menos código

# Configuraciones:
pd.set_option('display.max_columns', None) # Para mostrar todas las columnas del DataFrame
import warnings # Para controlar las advertencias
warnings.filterwarnings('ignore', category=FutureWarning) # Para ignorar las advertencias de tipo FutureWarning

# %%
df = pd.read_csv("files/world_data_full_apply_nulos.csv", index_col=0) # Cargar el DataFrame desde un archivo CSV

df.head() # Mostrar las primeras filas del DataFrame para verificar que se ha cargado correctamente
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...

# %% [markdown]
# 1. ¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos? Proporciona el porcentaje de países en ese continente.

# %%
#country y continent son dos variables categóricas

sns.barplot(data=df, x="country", hue="continent");

# %%
df_1 = df.groupby("continent")["country"].count().reset_index()

# %%
df_1.head()
# Out:
#          continent  country
# 0           Africa       53
# 1             Asia       45
# 2  Central America       20
# 3           Europe       47
# 4    North America        2

# %%
plt.pie(data=df_1, labels="continent", x="country", autopct=  '%1.1f%%');

# %%
sns.barplot(data=df_1, y="continent",x="country");

# %%
sns.boxplot(data=df, y="country", x="continent");

# %% [markdown]
# 2. ¿Cuáles son los 10 países con la mayor área forestal?

# %%
#country CATEGORICA, land_area CUANTITATIVA CONTINUA

#df[["country","land_area"]].value_counts().sort_values(ascending=False).head(10).reset_index()

df_2 = df.groupby("country")["land_area"].sum().sort_values(ascending=False).head(10).reset_index()

df_2
# Out:
#         country  land_area
# 0  S�����������    964.000
# 1      Tanzania    947.300
# 2       Nigeria    923.768
# 3     Venezuela    912.050
# 4       Namibia    824.292
# 5      Kiribati    811.000
# 6    Mozambique    799.380
# 7      Pakistan    796.095
# 8        Turkey    783.562
# 9       Bahrain    765.000

# %%
sns.barplot(data=df_2, y="country",x="land_area");

# %% [markdown]
# 3. ¿Cómo se distribuye la densidad de población entre los continentes?

# %%
#continent CATEGORICA, density CUANTITATIVA continua

sns.boxplot(data=df, y="continent", x="density");

# %% [markdown]
# 4. ¿Existe una relación entre el PIB y la tasa de desempleo de los países?

# %%
df.head(2)
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# ...

# %%
# pib es la variable gdp (Gross Domestic Product) numerica continua
# unemployment_rate numerica continua

sns.scatterplot(data=df,x="gdp",y="unemployment_rate");

# %%
sns.regplot(data=df,x="gdp",y="unemployment_rate");

# %%
sns.scatterplot(data=df,y="gdp",x="unemployment_rate");

# %%
sns.scatterplot(data=df,y="gdp",x="unemployment_rate",hue="continent");

# %%
sns.regplot(data=df,y="gdp",x="unemployment_rate");

# %%
#vamos a probar a agrupar para verlo más claro.

#country, gdp, unemployment_rate

df_4 = df.groupby("country")[["gdp","unemployment_rate"]].mean().reset_index()

df_4.head()
# Out:
#        country           gdp  unemployment_rate
# 0  Afghanistan  1.910135e+10              11.12
# 1      Albania  1.527808e+10              12.33
# 2      Algeria  1.699882e+11              11.70
# 3      Andorra  3.154058e+09                NaN
# 4       Angola  9.463542e+10               6.89

# %%
df_4 = df.groupby(["unemployment_rate","country"])["gdp"].mean().sort_values(ascending=False).reset_index()

df_4.head(2)
# Out:
#    unemployment_rate        country           gdp
# 0              14.70  United States  2.142770e+13
# 1               4.32          China  1.991000e+13

# %%
df[['unemployment_rate', 'gdp']].sort_values(by='unemployment_rate').head(10)
# Out:
#      unemployment_rate           gdp
# 141               0.09  1.834662e+11
# 125               0.47  1.292815e+10
# 159               0.58  1.425074e+09
# 92                0.63  1.817384e+10
# 30                0.68  2.708939e+10
# 12                0.71  3.857407e+10
# 173               0.75  5.436500e+11
# 144               1.03  1.012247e+10
# 176               1.12  4.503533e+08
# 121               1.41  3.064138e+10

# %%
df["pdcut"] = pd.cut(df['gdp'],bins = 3,labels=["bajo","medio","alto"])

# %%
df.head(2)
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# ...

# %%
sns.barplot(data=df,x="pdcut",y="unemployment_rate")
# Out:
# <Axes: xlabel='pdcut', ylabel='unemployment_rate'>

# %%
sns.countplot(data=df,x="pdcut");

# %%
sns.histplot(data=df,x="gdp", bins=3);
